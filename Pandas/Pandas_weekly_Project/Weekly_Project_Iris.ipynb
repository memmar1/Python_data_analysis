# %% [markdown]
# Iris
# Introduction:
# This exercise may seem a little bit strange, but keep doing it.
#
# Step 1. Import the necessary libraries

# %%
import pandas as pd
import datetime
import matplotlib as plt

# %% [markdown]
# Step 2. Import the dataset from this address.
# Step 3. Assign it to a variable called iris
# Step 4. Create columns for the dataset
# -sepal_length (in cm)
# -sepal_width (in cm)
# -petal_length (in cm)
# -petal_width (in cm)
# -class

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

# %%
columns = ["sepal_length (in cm)","sepal_width (in cm)","petal_length (in cm)","petal_width (in cm)","class"]

# %%
iris = pd.read_csv(url, header = None, names = columns)
iris
# Out:
#      sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# ..                    ...                  ...                   ...
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      petal_width (in cm)           class
# 0                    0.2     Iris-setosa
# 1                    0.2     Iris-setosa
# ...

# %% [markdown]
# Step 5. Is there any missing value in the dataframe?

# %%
iris.isna().any().any()
# Out:
# False

# %% [markdown]
# Step 6. Lets set the values of the rows 10 to 29 of the column 'petal_length' to NaN

# %%
iris.loc[10:29,"petal_length (in cm)"] = None

# %%
iris.loc[8:30,"petal_length (in cm)":]
# Out:
#     petal_length (in cm)  petal_width (in cm)        class
# 8                    1.4                  0.2  Iris-setosa
# 9                    1.5                  0.1  Iris-setosa
# 10                   NaN                  0.2  Iris-setosa
# 11                   NaN                  0.2  Iris-setosa
# 12                   NaN                  0.1  Iris-setosa
# 13                   NaN                  0.1  Iris-setosa
# 14                   NaN                  0.2  Iris-setosa
# 15                   NaN                  0.4  Iris-setosa
# 16                   NaN                  0.4  Iris-setosa
# 17                   NaN                  0.3  Iris-setosa
# 18                   NaN                  0.3  Iris-setosa
# 19                   NaN                  0.3  Iris-setosa
# 20                   NaN                  0.2  Iris-setosa
# 21                   NaN                  0.4  Iris-setosa
# 22                   NaN                  0.2  Iris-setosa
# ...

# %%
Step 7. Good, now lets substitute the NaN values to 1.0

# %%
iris.loc[10:29,"petal_length (in cm)"] = 1.0

# %%
iris.loc[8:30,"petal_length (in cm)":]
# Out:
#     petal_length (in cm)  petal_width (in cm)        class
# 8                    1.4                  0.2  Iris-setosa
# 9                    1.5                  0.1  Iris-setosa
# 10                   1.0                  0.2  Iris-setosa
# 11                   1.0                  0.2  Iris-setosa
# 12                   1.0                  0.1  Iris-setosa
# 13                   1.0                  0.1  Iris-setosa
# 14                   1.0                  0.2  Iris-setosa
# 15                   1.0                  0.4  Iris-setosa
# 16                   1.0                  0.4  Iris-setosa
# 17                   1.0                  0.3  Iris-setosa
# 18                   1.0                  0.3  Iris-setosa
# 19                   1.0                  0.3  Iris-setosa
# 20                   1.0                  0.2  Iris-setosa
# 21                   1.0                  0.4  Iris-setosa
# 22                   1.0                  0.2  Iris-setosa
# ...

# %% [markdown]
# Step 8. Now let's delete the column class

# %%
iris.drop("class", axis = 1, inplace = True)

# %%
iris.head()
# Out:
#    sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
#
#    petal_width (in cm)
# 0                  0.2
# 1                  0.2
# 2                  0.2
# 3                  0.2
# 4                  0.2

# %% [markdown]
# Step 9. Set the first 3 rows as NaN

# %%
iris.iloc[0:3] = None

# %%
iris.head()
# Out:
#    sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                   NaN                  NaN                   NaN
# 1                   NaN                  NaN                   NaN
# 2                   NaN                  NaN                   NaN
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
#
#    petal_width (in cm)
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  0.2
# 4                  0.2

# %% [markdown]
# Step 10. Delete the rows that have NaN

# %%
iris.dropna(inplace = True)

# %%
iris.head()
# Out:
#    sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
#
#    petal_width (in cm)
# 3                  0.2
# 4                  0.2
# 5                  0.4
# 6                  0.3
# 7                  0.2

# %% [markdown]
# Step 11. Reset the index so it begins with 0 again

# %%
iris.reset_index(drop=True, inplace=True)

# %%
iris.head()
# Out:
#    sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                   4.6                  3.1                   1.5
# 1                   5.0                  3.6                   1.4
# 2                   5.4                  3.9                   1.7
# 3                   4.6                  3.4                   1.4
# 4                   5.0                  3.4                   1.5
#
#    petal_width (in cm)
# 0                  0.2
# 1                  0.2
# 2                  0.4
# 3                  0.3
# 4                  0.2

# %%
find the mean of the dataframe

# %%
iris.mean()
# Out:
# sepal_length (in cm)    5.862585
# sepal_width (in cm)     3.050340
# petal_length (in cm)    3.741497
# petal_width (in cm)     1.219048
# dtype: float64
